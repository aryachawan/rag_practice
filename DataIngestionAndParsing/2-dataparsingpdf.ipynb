# %% [markdown]
# Loading PDF files

# %%
# libraries needed for loading files
from langchain_community.document_loaders import (
    PyPDFLoader,
    PyMuPDFLoader,
    UnstructuredPDFLoader
)

# %% [markdown]
# 1>  PyPDFLoader

# %%
try:
    pypdf_loader = PyPDFLoader("data/pdf_files/Scnotes.pdf")
    pypdf_docs = pypdf_loader.load()
    print(pypdf_docs)
except Exception as e:
    print(f"Error: {e}")
